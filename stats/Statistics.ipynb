# %%
import pandas as pd
import numpy as np
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('CardioGoodFitness-1.csv')
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# unique         NaN            NaN         NaN
# top            NaN            NaN         NaN
# freq           NaN            NaN         NaN
# mean      3.311111   53719.577778  103.194444
# std       0.958869   16506.684226   51.863605
# min       1.000000   29562.000000   21.000000
# 25%       3.000000   44058.750000   66.000000
# 50%       3.000000   50596.500000   94.000000
# 75%       4.000000   58668.000000  114.750000
# max       5.000000  104581.000000  360.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.hist(figsize=(10,12))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.boxplot(x='Gender',y='Age',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
pd.crosstab(df['Product'],df['Gender'])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
pd.crosstab(df['Product'],df['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
sns.countplot(x='Product',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
pd.pivot_table(df,index=['Product','Gender'],columns=['MaritalStatus'],aggfunc=len)
# Out:
#                      Age        Education          Fitness           Income  \
# MaritalStatus  Partnered Single Partnered Single Partnered Single Partnered
# Product Gender
# TM195   Female        27     13        27     13        27     13        27
#         Male          21     19        21     19        21     19        21
# TM498   Female        15     14        15     14        15     14        15
#         Male          21     10        21     10        21     10        21
# TM798   Female         4      3         4      3         4      3         4
#         Male          19     14        19     14        19     14        19
#
#                           Miles            Usage
# MaritalStatus  Single Partnered Single Partnered Single
# Product Gender
# TM195   Female     13        27     13        27     13
#         Male       19        21     19        21     19
# TM498   Female     14        15     14        15     14
#         Male       10        21     10        21     10
# TM798   Female      3         4      3         4      3
#         Male       14        19     14        19     14

# %%
pd.pivot_table(df,'Income',index=['Product','Gender'],columns=['MaritalStatus'],aggfunc=len)
# Out:
# MaritalStatus   Partnered  Single
# Product Gender
# TM195   Female         27      13
#         Male           21      19
# TM498   Female         15      14
#         Male           21      10
# TM798   Female          4       3
#         Male           19      14

# %%
pd.pivot_table(df,'Miles',index=['Product','Gender'],columns=['MaritalStatus'],aggfunc=len)
# Out:
# MaritalStatus   Partnered  Single
# Product Gender
# TM195   Female         27      13
#         Male           21      19
# TM498   Female         15      14
#         Male           21      10
# TM798   Female          4       3
#         Male           19      14

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['Age'].std()
# Out:
# 6.943498135399795

# %%
df['Age'].mean()
# Out:
# 28.788888888888888

# %%
sns.displot(df['Age'],kde=True)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.hist(by='Gender',column='Age')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df.hist(by='Product',column='Miles',figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'TM195'}>,
#         <Axes: title={'center': 'TM498'}>],
#        [<Axes: title={'center': 'TM798'}>, <Axes: >]], dtype=object)

# %%
non_numeric_columns = df.columns[df.dtypes == 'object']
print("Non-numeric columns:", non_numeric_columns)
# Out:
# Non-numeric columns: Index(['Product', 'Gender', 'MaritalStatus'], dtype='object')

# %%
df_numeric = df.drop(columns=non_numeric_columns)

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
corr = df.corr()
print(corr)
# Out:
#                Product       Age  Gender  Education  MaritalStatus     Usage  \
# Product            NaN       NaN     NaN        NaN            NaN       NaN
# Age                NaN  1.000000     NaN   0.280496            NaN  0.015064
# Gender             NaN       NaN     NaN        NaN            NaN       NaN
# Education          NaN  0.280496     NaN   1.000000            NaN  0.395155
# MaritalStatus      NaN       NaN     NaN        NaN            NaN       NaN
# Usage              NaN  0.015064     NaN   0.395155            NaN  1.000000
# Fitness            NaN  0.061105     NaN   0.410581            NaN  0.668606
# Income             NaN  0.513414     NaN   0.625827            NaN  0.519537
# Miles              NaN  0.036618     NaN   0.307284            NaN  0.759130
#
#                 Fitness    Income     Miles
# Product             NaN       NaN       NaN
# Age            0.061105  0.513414  0.036618
# Gender              NaN       NaN       NaN
# Education      0.410581  0.625827  0.307284
# MaritalStatus       NaN       NaN       NaN
# Usage          0.668606  0.519537  0.759130
# Fitness        1.000000  0.535005  0.785702
# Income         0.535005  1.000000  0.543473
# Miles          0.785702  0.543473  1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
cov = df.cov()

# %%
cov
# Out:
#                Product           Age  Gender     Education  MaritalStatus  \
# Product            NaN           NaN     NaN           NaN            NaN
# Age                NaN     48.212166     NaN      3.149410            NaN
# Gender             NaN           NaN     NaN           NaN            NaN
# Education          NaN      3.149410     NaN      2.614867            NaN
# MaritalStatus      NaN           NaN     NaN           NaN            NaN
# Usage              NaN      0.113470     NaN      0.693172            NaN
# Fitness            NaN      0.406828     NaN      0.636623            NaN
# Income             NaN  58844.463439     NaN  16704.717815            NaN
# Miles              NaN     13.186530     NaN     25.770795            NaN
#
#                      Usage      Fitness        Income          Miles
# Product                NaN          NaN           NaN            NaN
# Age               0.113470     0.406828  5.884446e+04      13.186530
# Gender                 NaN          NaN           NaN            NaN
# Education         0.693172     0.636623  1.670472e+04      25.770795
# MaritalStatus          NaN          NaN           NaN            NaN
# Usage             1.176785     0.695469  9.303043e+03      42.709808
# Fitness           0.695469     0.919429  8.467925e+03      39.073246
# Income         9303.042582  8467.925388  2.724706e+08  465265.361887
# Miles            42.709808    39.073246  4.652654e+05    2689.833489

# %%
from sklearn import linear_model

# %%
x = df[['Miles']]  # Ensuring x is a 2D DataFrame
y = df[['Usage', 'Fitness']]  # y can remain a 2D DataFrame

# Initialize and fit the model
regr = linear_model.LinearRegression()
regr.fit(x, y)
# Out:
# LinearRegression()

# %%
regr.coef_
# Out:
# array([[0.01587823],
#        [0.01452627]])

# %%
regr.intercept_
# Out:
# array([1.81700994, 1.81208079])
